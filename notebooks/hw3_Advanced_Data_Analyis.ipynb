# %%
import pandas as pd

# %%
# !ls
# Out:
# Popular_Baby_Names.csv	sample_data

# %%
df=pd.read_csv('Popular_Baby_Names.csv')
df.head()
# Out:
#    Year of Birth  Gender                   Ethnicity Child's First Name  \
# 0           2016  FEMALE  ASIAN AND PACIFIC ISLANDER             Olivia
# 1           2016  FEMALE  ASIAN AND PACIFIC ISLANDER              Chloe
# 2           2016  FEMALE  ASIAN AND PACIFIC ISLANDER             Sophia
# 3           2016  FEMALE  ASIAN AND PACIFIC ISLANDER              Emily
# 4           2016  FEMALE  ASIAN AND PACIFIC ISLANDER               Emma
#
#    Count  Rank
# 0    172     1
# 1    112     2
# 2    104     3
# 3     99     4
# 4     99     4

# %%
df.tail()
# Out:
#        Year of Birth Gender           Ethnicity Child's First Name  Count  \
# 19413           2011   MALE  WHITE NON HISPANIC            STEPHEN     10
# 19414           2011   MALE  WHITE NON HISPANIC            STEPHEN     10
# 19415           2011   MALE  WHITE NON HISPANIC              DEREK     10
# 19416           2011   MALE  WHITE NON HISPANIC            BENNETT     10
# 19417           2011   MALE  WHITE NON HISPANIC              ELLIS     10
#
#        Rank
# 19413    97
# 19414    97
# 19415    97
# 19416    97
# 19417    97

# %%
pd.options.display.max_rows = 3000
pd.options.display.max_columns = 50
df.head()
# Out:
#    Year of Birth  Gender                   Ethnicity Child's First Name  \
# 0           2016  FEMALE  ASIAN AND PACIFIC ISLANDER             Olivia
# 1           2016  FEMALE  ASIAN AND PACIFIC ISLANDER              Chloe
# 2           2016  FEMALE  ASIAN AND PACIFIC ISLANDER             Sophia
# 3           2016  FEMALE  ASIAN AND PACIFIC ISLANDER              Emily
# 4           2016  FEMALE  ASIAN AND PACIFIC ISLANDER               Emma
#
#    Count  Rank
# 0    172     1
# 1    112     2
# 2    104     3
# 3     99     4
# 4     99     4

# %%
list(df)
# Out:
# ['Year of Birth', 'Gender', 'Ethnicity', "Child's First Name", 'Count', 'Rank']

# %%
ethnicity=df.groupby('Ethnicity')
ethnicity.describe()
# Out:
#                            Year of Birth                                 \
#                                    count         mean       std     min
# Ethnicity
# ASIAN AND PACI                     693.0  2012.000000  0.000000  2012.0
# ASIAN AND PACIFIC ISLANDER        2693.0  2013.497215  1.652953  2011.0
# BLACK NON HISP                     681.0  2012.000000  0.000000  2012.0
# BLACK NON HISPANIC                2826.0  2013.324133  1.682086  2011.0
# HISPANIC                          5714.0  2013.068428  1.604641  2011.0
# WHITE NON HISP                    1338.0  2012.000000  0.000000  2012.0
# WHITE NON HISPANIC                5473.0  2013.453134  1.661628  2011.0
#
#                                                              Count             \
#                                25%     50%     75%     max   count       mean
# Ethnicity
# ASIAN AND PACI              2012.0  2012.0  2012.0  2012.0   693.0  28.116883
# ...

# %%
gender_and_ethnicity=df.groupby(['Gender', 'Ethnicity'])
gender_and_ethnicity.describe()
# Out:
#                                   Year of Birth                         \
#                                           count         mean       std
# Gender Ethnicity
# FEMALE ASIAN AND PACI                     350.0  2012.000000  0.000000
#        ASIAN AND PACIFIC ISLANDER        1343.0  2013.474311  1.651641
#        BLACK NON HISP                     330.0  2012.000000  0.000000
#        BLACK NON HISPANIC                1400.0  2013.357857  1.674284
#        HISPANIC                          2937.0  2013.057882  1.609551
#        WHITE NON HISP                     712.0  2012.000000  0.000000
#        WHITE NON HISPANIC                2861.0  2013.454387  1.657711
# MALE   ASIAN AND PACI                     343.0  2012.000000  0.000000
#        ASIAN AND PACIFIC ISLANDER        1350.0  2013.520000  1.654555
#        BLACK NON HISP                     351.0  2012.000000  0.000000
#        BLACK NON HISPANIC                1426.0  2013.291024  1.689643
# ...

# %%
import datetime

# %%
df.reset_index().head()
# Out:
#    index  Year of Birth  Gender                   Ethnicity  \
# 0      0           2016  FEMALE  ASIAN AND PACIFIC ISLANDER
# 1      1           2016  FEMALE  ASIAN AND PACIFIC ISLANDER
# 2      2           2016  FEMALE  ASIAN AND PACIFIC ISLANDER
# 3      3           2016  FEMALE  ASIAN AND PACIFIC ISLANDER
# 4      4           2016  FEMALE  ASIAN AND PACIFIC ISLANDER
#
#   Child's First Name  Count  Rank
# 0             Olivia    172     1
# 1              Chloe    112     2
# 2             Sophia    104     3
# 3              Emily     99     4
# 4               Emma     99     4

# %%
df.head()
# Out:
#    Year of Birth  Gender                   Ethnicity Child's First Name  \
# 0           2016  FEMALE  ASIAN AND PACIFIC ISLANDER             Olivia
# 1           2016  FEMALE  ASIAN AND PACIFIC ISLANDER              Chloe
# 2           2016  FEMALE  ASIAN AND PACIFIC ISLANDER             Sophia
# 3           2016  FEMALE  ASIAN AND PACIFIC ISLANDER              Emily
# 4           2016  FEMALE  ASIAN AND PACIFIC ISLANDER               Emma
#
#    Count  Rank
# 0    172     1
# 1    112     2
# 2    104     3
# 3     99     4
# 4     99     4

# %%
list(df)
# Out:
# ['Year of Birth', 'Gender', 'Ethnicity', "Child's First Name", 'Count', 'Rank']

# %%
df['Year of Birth']=pd.to_datetime(df['Year of Birth'],format='%Y-%m-%d %H:%M:%S')

# %%
df.head()
# Out:
#                   Year of Birth  Gender                   Ethnicity  \
# 0 1970-01-01 00:00:00.000002016  FEMALE  ASIAN AND PACIFIC ISLANDER
# 1 1970-01-01 00:00:00.000002016  FEMALE  ASIAN AND PACIFIC ISLANDER
# 2 1970-01-01 00:00:00.000002016  FEMALE  ASIAN AND PACIFIC ISLANDER
# 3 1970-01-01 00:00:00.000002016  FEMALE  ASIAN AND PACIFIC ISLANDER
# 4 1970-01-01 00:00:00.000002016  FEMALE  ASIAN AND PACIFIC ISLANDER
#
#   Child's First Name  Count  Rank
# 0             Olivia    172     1
# 1              Chloe    112     2
# 2             Sophia    104     3
# 3              Emily     99     4
# 4               Emma     99     4

# %%
df = df.set_index('Year of Birth')

# %%
df.head()
# Out:
#                                Gender                   Ethnicity  \
# Year of Birth
# 1970-01-01 00:00:00.000002016  FEMALE  ASIAN AND PACIFIC ISLANDER
# 1970-01-01 00:00:00.000002016  FEMALE  ASIAN AND PACIFIC ISLANDER
# 1970-01-01 00:00:00.000002016  FEMALE  ASIAN AND PACIFIC ISLANDER
# 1970-01-01 00:00:00.000002016  FEMALE  ASIAN AND PACIFIC ISLANDER
# 1970-01-01 00:00:00.000002016  FEMALE  ASIAN AND PACIFIC ISLANDER
#
#                               Child's First Name  Count  Rank
# Year of Birth
# 1970-01-01 00:00:00.000002016             Olivia    172     1
# 1970-01-01 00:00:00.000002016              Chloe    112     2
# 1970-01-01 00:00:00.000002016             Sophia    104     3
# 1970-01-01 00:00:00.000002016              Emily     99     4
# 1970-01-01 00:00:00.000002016               Emma     99     4

# %%
import numpy as np

periods = df.resample('M').count() # let's group by month 
periods
# Out:
#                Gender  Ethnicity  Child's First Name  Count   Rank
# Year of Birth
# 1970-01-31      19418      19418               19418  19418  19418

# %%
start_date = '2016-10-31' # set an arbitray start date
end_date = '2018-06-30' # set an arbitray end date

mask = (df.index > start_date) & (df.index <= end_date) # create our mask

# %%
# Out:
# Empty DataFrame
# Columns: [Gender, Ethnicity, Child's First Name, Count, Rank]
# Index: []
