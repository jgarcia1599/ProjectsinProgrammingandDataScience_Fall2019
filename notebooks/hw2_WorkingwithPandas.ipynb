# %%
import pandas as pd # importing the Pandas library

# %%
# !ls
# Out:
# Datafiniti_Pizza_Restaurants_and_the_Pizza_They_Sell_May19.csv	sample_data

# %%
df=pd.read_csv('Datafiniti_Pizza_Restaurants_and_the_Pizza_They_Sell_May19.csv')
df.head()
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AVz3Y-7h3D1zeR_xDAqm  2017-06-30T05:05:40Z  2019-05-01T15:43:09Z
# 1  AVweGPFF_7pvs4fzAAzQ  2016-04-02T04:02:49Z  2019-05-01T15:27:50Z
# 2  AVwdRGa9_7pvs4fz4E3K  2016-03-03T18:39:49Z  2019-05-01T12:52:25Z
# 3  AVwdX4psIN2L1WUfvJB1  2016-03-29T05:08:59Z  2019-05-01T12:52:20Z
# 4  AVwdaeTtkufWRAb55pSH  2016-03-31T02:34:04Z  2019-05-01T12:50:45Z
#
#              address                                         categories  \
# 0   4203 E Kiehl Ave  Pizza,Restaurant,American restaurants,Pizza Pl...
# 1  25 E Camelback Rd                      Pizza,Pizza Place,Restaurants
# 2    3703 Paxton Ave                 Restaurant,Pizza Place,Restaurants
# 3    30495 John R Rd       Pizza,Carry-out food,Pizza Place,Restaurants
# 4   3600 Eastern Ave  Pizza,American restaurants,Pizza Place,Pizza e...
#
#                primaryCategories             city country  \
# 0  Accommodation & Food Services         Sherwood      US
# ...

# %%
df.tail()
# Out:
#                         id             dateAdded           dateUpdated  \
# 9995  AVwdKXFYByjofQCxmIyZ  2016-03-21T00:12:46Z  2018-01-08T10:25:27Z
# 9996  AVwdKXFYByjofQCxmIyZ  2016-03-21T00:12:46Z  2018-01-08T10:25:27Z
# 9997  AVz6kzsQFcQ3k02bDhwQ  2017-06-30T19:56:11Z  2018-01-07T10:51:29Z
# 9998  AVz6kzsQFcQ3k02bDhwQ  2017-06-30T19:56:11Z  2018-01-07T10:51:29Z
# 9999  AVwdG9zTkufWRAb52Y2A  2015-10-23T01:57:27Z  2018-01-04T17:57:59Z
#
#                     address                              categories  \
# 9995      1126 E Lovejoy St                             Pizza Place
# 9996      1126 E Lovejoy St                             Pizza Place
# 9997         3641 E Main St                 Pizza Place,Restaurants
# 9998         3641 E Main St                 Pizza Place,Restaurants
# 9999  7460 W Lake Mead Blvd  Pizza Place,Restaurant,Fast Food,Pizza
#
#                   primaryCategories           city country  \
# 9995  Accommodation & Food Services        Buffalo      US
# ...

# %%
pd.options.display.max_rows = 3000
pd.options.display.max_columns = 50
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3ca4897b8593> in <module>()
# ----> 1 pd.options.display.max_rows = 3000
#       2 pd.options.display.max_columns = 50
#       3 df.head()
#
# NameError: name 'pd' is not defined

# %%
list(df)
# Out:
# ['id',
#  'dateAdded',
#  'dateUpdated',
#  'address',
#  'categories',
#  'primaryCategories',
#  'city',
#  'country',
#  'keys',
#  'latitude',
#  'longitude',
#  'menuPageURL',
#  'menus.amountMax',
#  'menus.amountMin',
#  'menus.currency',
#  'menus.dateSeen',
#  'menus.description',
#  'menus.name',
#  'name',
#  'postalCode',
#  'priceRangeCurrency',
#  'priceRangeMin',
#  'priceRangeMax',
#  'province']

# %%
df=df.drop(df.columns[0],axis=1)#I will drop the axis column as i find it redundant 
df.head()
# Out:
#               dateAdded           dateUpdated            address  \
# 0  2017-06-30T05:05:40Z  2019-05-01T15:43:09Z   4203 E Kiehl Ave
# 1  2016-04-02T04:02:49Z  2019-05-01T15:27:50Z  25 E Camelback Rd
# 2  2016-03-03T18:39:49Z  2019-05-01T12:52:25Z    3703 Paxton Ave
# 3  2016-03-29T05:08:59Z  2019-05-01T12:52:20Z    30495 John R Rd
# 4  2016-03-31T02:34:04Z  2019-05-01T12:50:45Z   3600 Eastern Ave
#
#                                           categories  \
# 0  Pizza,Restaurant,American restaurants,Pizza Pl...
# 1                      Pizza,Pizza Place,Restaurants
# 2                 Restaurant,Pizza Place,Restaurants
# 3       Pizza,Carry-out food,Pizza Place,Restaurants
# 4  Pizza,American restaurants,Pizza Place,Pizza e...
#
#                primaryCategories             city country  \
# 0  Accommodation & Food Services         Sherwood      US
# 1  Accommodation & Food Services          Phoenix      US
# 2  Accommodation & Food Services       Cincinnati      US
# ...

# %%
df.describe(include='all')
# Out:
#                    dateAdded           dateUpdated            address  \
# count                  10000                 10000              10000
# unique                  2214                  2193               2278
# top     2017-06-19T14:50:25Z  2018-06-29T19:34:53Z  6501 Kissena Blvd
# freq                      72                    68                 68
# mean                     NaN                   NaN                NaN
# std                      NaN                   NaN                NaN
# min                      NaN                   NaN                NaN
# 25%                      NaN                   NaN                NaN
# 50%                      NaN                   NaN                NaN
# 75%                      NaN                   NaN                NaN
# max                      NaN                   NaN                NaN
#
#                     categories              primaryCategories      city  \
# ...

# %%
df.count()
# Out:
# dateAdded             10000
# dateUpdated           10000
# address               10000
# categories            10000
# primaryCategories     10000
# city                  10000
# country               10000
# keys                  10000
# latitude              10000
# longitude             10000
# menuPageURL            1679
# menus.amountMax       10000
# menus.amountMin       10000
# menus.currency        10000
# menus.dateSeen        10000
# menus.description      3718
# menus.name            10000
# name                  10000
# postalCode             9996
# priceRangeCurrency    10000
# priceRangeMin         10000
# priceRangeMax         10000
# province              10000
# dtype: int64

# %%
df['country'].count()
# Out:
# 10000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 23 columns):
# dateAdded             10000 non-null object
# dateUpdated           10000 non-null object
# address               10000 non-null object
# categories            10000 non-null object
# primaryCategories     10000 non-null object
# city                  10000 non-null object
# country               10000 non-null object
# keys                  10000 non-null object
# latitude              10000 non-null float64
# longitude             10000 non-null float64
# menuPageURL           1679 non-null object
# menus.amountMax       10000 non-null float64
# menus.amountMin       10000 non-null float64
# menus.currency        10000 non-null object
# menus.dateSeen        10000 non-null object
# menus.description     3718 non-null object
# menus.name            10000 non-null object
# name                  10000 non-null object
# postalCode            9996 non-null object
# ...

# %%
df.describe()
# Out:
#            latitude     longitude  menus.amountMax  menus.amountMin  \
# count  10000.000000  10000.000000     10000.000000     10000.000000
# mean      38.371895    -90.063800        14.032670        13.416902
# std        4.573537     17.340379        17.607233        10.742678
# min       21.421326   -157.802443         0.000000         0.000000
# 25%       34.422946   -104.801126         8.490000         8.000000
# 50%       40.118880    -82.909949        13.390000        12.990000
# 75%       40.905048    -75.194741        17.950000        16.990000
# max       64.850500    -71.946170      1395.000000       243.000000
#
#        priceRangeMin  priceRangeMax
# count   10000.000000   10000.000000
# mean        4.655500      27.764200
# std         9.828412       6.017526
# min         0.000000       7.000000
# 25%         0.000000      25.000000
# 50%         0.000000      25.000000
# 75%         0.000000      25.000000
# max        50.000000      55.000000

# %%
df['dateAdded']=pd.to_datetime(df['dateAdded'])
df['dateUpdated']=pd.to_datetime(df['dateUpdated'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 23 columns):
# dateAdded             10000 non-null datetime64[ns, UTC]
# dateUpdated           10000 non-null datetime64[ns, UTC]
# address               10000 non-null object
# categories            10000 non-null object
# primaryCategories     10000 non-null object
# city                  10000 non-null object
# country               10000 non-null object
# keys                  10000 non-null object
# latitude              10000 non-null float64
# longitude             10000 non-null float64
# menuPageURL           1679 non-null object
# menus.amountMax       10000 non-null float64
# menus.amountMin       10000 non-null float64
# menus.currency        10000 non-null object
# menus.dateSeen        10000 non-null object
# menus.description     3718 non-null object
# menus.name            10000 non-null object
# name                  10000 non-null object
# ...

# %%
df.sort_values(by=['dateAdded'], ascending=False)#sorted the values on date added as I want to know which pizza restaurant was added recently
df.head()
# Out:
#                   dateAdded               dateUpdated            address  \
# 0 2017-06-30 05:05:40+00:00 2019-05-01 15:43:09+00:00   4203 E Kiehl Ave
# 1 2016-04-02 04:02:49+00:00 2019-05-01 15:27:50+00:00  25 E Camelback Rd
# 2 2016-03-03 18:39:49+00:00 2019-05-01 12:52:25+00:00    3703 Paxton Ave
# 3 2016-03-29 05:08:59+00:00 2019-05-01 12:52:20+00:00    30495 John R Rd
# 4 2016-03-31 02:34:04+00:00 2019-05-01 12:50:45+00:00   3600 Eastern Ave
#
#                                           categories  \
# 0  Pizza,Restaurant,American restaurants,Pizza Pl...
# 1                      Pizza,Pizza Place,Restaurants
# 2                 Restaurant,Pizza Place,Restaurants
# 3       Pizza,Carry-out food,Pizza Place,Restaurants
# 4  Pizza,American restaurants,Pizza Place,Pizza e...
#
#                primaryCategories             city country  \
# 0  Accommodation & Food Services         Sherwood      US
# 1  Accommodation & Food Services          Phoenix      US
# ...
